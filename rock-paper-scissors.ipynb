# %%
import random

def play():
    print("Welcome to Rock, Paper, Scissors!")
    choices = ["rock", "paper", "scissors"]

    while True:
        user = input("Enter your choice (rock/paper/scissors or quit to stop): ").lower()

        if user == "quit":
            print("Thanks for playing! Goodbye 👋")
            break

        if user not in choices:
            print("Invalid choice! Please enter rock, paper, or scissors.")
            continue

        computer = random.choice(choices)
        print(f"Computer chose: {computer}")

        if user == computer:
            print("It's a tie!")
        elif (user == "rock" and computer == "scissors") or \
             (user == "paper" and computer == "rock") or \
             (user == "scissors" and computer == "paper"):
            print("You win! 🎉")
        else:
            print("You lose! 😢")

        print()  # blank line for readability

if __name__ == "__main__":
    play()
# Out:
# Welcome to Rock, Paper, Scissors!
# Enter your choice (rock/paper/scissors or quit to stop):  roc
# Invalid choice! Please enter rock, paper, or scissors.
# Enter your choice (rock/paper/scissors or quit to stop):  rock
# Computer chose: rock
# It's a tie!
# Enter your choice (rock/paper/scissors or quit to stop):  paper
# Computer chose: scissors
# You lose! 😢
# Enter your choice (rock/paper/scissors or quit to stop):  scissors
# Computer chose: scissors
# It's a tie!
# Enter your choice (rock/paper/scissors or quit to stop):  rock
# Computer chose: rock
# It's a tie!
# Enter your choice (rock/paper/scissors or quit to stop):  rock
# Computer chose: rock
# It's a tie!
# Enter your choice (rock/paper/scissors or quit to stop):  paper
# Computer chose: rock
# You win! 🎉
# Enter your choice (rock/paper/scissors or quit to stop):  paper
# Computer chose: paper
# It's a tie!
# Enter your choice (rock/paper/scissors or quit to stop):  quit
# Thanks for playing! Goodbye 👋
